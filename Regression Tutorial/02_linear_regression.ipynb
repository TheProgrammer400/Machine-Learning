# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# ## Data Preprocessing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("../Data/salaryData.csv")
dataset
# Out:
#     YearsExperience  Salary
# 0               1.1   39343
# 1               1.3   46205
# 2               1.5   37731
# 3               2.0   43525
# 4               2.2   39891
# 5               2.9   56642
# 6               3.0   60150
# 7               3.2   54445
# 8               3.2   64445
# 9               3.7   57189
# 10              3.9   63218
# 11              4.0   55794
# 12              4.0   56957
# 13              4.1   57081
# 14              4.5   61111
# 15              4.9   67938
# 16              5.1   66029
# 17              5.3   83088
# 18              5.9   81363
# 19              6.0   93940
# 20              6.8   91738
# 21              7.1   98273
# 22              7.9  101302
# 23              8.2  113812
# 24              8.7  109431
# 25              9.0  105582
# 26              9.5  116969
# 27              9.6  112635
# 28             10.3  122391
# 29             10.5  121872

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values
X, y
# Out:
# (array([[ 1.1],
#         [ 1.3],
#         [ 1.5],
#         [ 2. ],
#         [ 2.2],
#         [ 2.9],
#         [ 3. ],
#         [ 3.2],
#         [ 3.2],
#         [ 3.7],
#         [ 3.9],
#         [ 4. ],
#         [ 4. ],
#         [ 4.1],
#         [ 4.5],
#         [ 4.9],
#         [ 5.1],
#         [ 5.3],
#         [ 5.9],
#         [ 6. ],
#         [ 6.8],
#         [ 7.1],
#         [ 7.9],
#         [ 8.2],
#         [ 8.7],
#         [ 9. ],
#         [ 9.5],
#         [ 9.6],
#         [10.3],
#         [10.5]]),
#  array([ 39343,  46205,  37731,  43525,  39891,  56642,  60150,  54445,
#          64445,  57189,  63218,  55794,  56957,  57081,  61111,  67938,
#          66029,  83088,  81363,  93940,  91738,  98273, 101302, 113812,
#         109431, 105582, 116969, 112635, 122391, 121872]))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

# %% [markdown]
# ## Training the Simple Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train) # this actually trains the model
# Out:
# LinearRegression()

# %% [markdown]
# ## How does `.fit()` method trains the model
#
# In `sklearn LinearRegression` specifically, no loops are used for training.
#
# Insead, it uses powerful linera algebra directly:
#
# $$
# \theta = (X^TX)^{-1}X^Ty
# $$
#
# This formula directly computes the optimal weights.

# %% [markdown]
# ## Testing the model

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ## Visualize training set results

# %%
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, model.predict(X_train), color = 'blue')
plt.title('Salary vs. Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Visualize Testing Set

# %%
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_test, model.predict(X_test), color = 'blue')
plt.title('Salary vs. Experience (Test set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()
